# %%
from backend import chat_gemini, checkpoint

# %%
data = []
temp = []
for i in checkpoint.list(None):
    print(temp)
    # print(i.checkpoint)
    # haha = i.checkpoint
    # break
    print(i.config)
    if i.config['configurable']['thread_id'] not in temp:
        data.append({"thread_id": i.config['configurable']['thread_id'], "smart_name": i.checkpoint['channel_values']['smart_name']})
        temp.append(i.config['configurable']['thread_id'])
# Out:
# {'configurable': {'thread_id': 'thread_2', 'checkpoint_ns': '', 'checkpoint_id': '1f16e048-6c18-62dc-8008-4f8c45ec97cb'}}
# {'configurable': {'thread_id': 'thread_2', 'checkpoint_ns': '', 'checkpoint_id': '1f16e048-6387-6f30-8007-3a0c9e931d30'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 8
#       4     # haha = i.checkpoint
#       5     # break
#       6     print(i.config)
#       7     if i.config['configurable']['thread_id'] not in data:
# ----> 8         data.append({"thread_id": i.config['configurable']['thread_id'], "smart_name": i.checkpoint['channel_values']['smart_name']})
#       9         # temp.append(i.config['configurable']['thread_id'])
#
# KeyError: 'smart_name'

# %%
def retrive_all_threads():
    data = []
    temp = []
    for i in checkpoint.list(None):
        if i.config['configurable']['thread_id'] not in temp:
            data.append({"thread_id": i.config['configurable']['thread_id'], "smart_name": i.checkpoint['channel_values']['smart_name']})
            temp.append(i.config['configurable']['thread_id'])
    return data

# %%
x = retrive_all_threads()
print(x)
# Out:
# [{'thread_id': 'thread_2', 'smart_name': 'Joke Request Session'}, {'thread_id': 'thread_1', 'smart_name': 'Friendly Greeting'}]

# %%
for i in haha['channel_values']:
    print(i)
# Out:
# messages
# smart_name
# boolean_to_create_smart_name

# %%
haha['channel_values']['smart_name']
# Out:
# 'Joke Request Session'
